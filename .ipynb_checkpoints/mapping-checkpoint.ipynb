# %%
import folium
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import geopandas as gpd
import numpy as np
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
district_list = pd.read_csv('C:/Users/ballinj/housing/london_district_codes.csv', index_col=False)['district'].tolist()
district_links = pd.read_csv('london_district_codes.csv')
district_shape_file = 'C:/Users/ballinj/housing/ballinger_house_hunter/london_postal_districts_wgs84.shp'

# %%
bermondsey_df = pd.read_csv('data/rightmove/housing_data_22-02-2019.csv', index_col=0)
bermondsey_df = bermondsey_df.dropna()
bermondsey_df['price'] = bermondsey_df['price'].str.replace('£','')
bermondsey_df = bermondsey_df[bermondsey_df['price']!='Coming Soon']
bermondsey_df['price'] = pd.to_numeric(bermondsey_df['price'].str.replace(',',''))
bermondsey_df = bermondsey_df.reset_index(drop=True)

# %%
london_df = pd.read_csv('data/london/rightmove/properties_by_district_2019-03-02.csv')
london_df = london_df[(london_df['price'] != 'POA') & (london_df['price'] != 'Offers Invited') & (london_df['price'] != 'Coming Soon')]
london_df['price'] = pd.to_numeric(london_df['price'])
london_df = london_df.reset_index(drop=True)
london_df['added/reduced_date'] = pd.to_datetime(london_df['added/reduced_date'], format='%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Offers in Excess of
#
# 					450000"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f6006836e19f> in <module>()
#       1 london_df = pd.read_csv('data/london/rightmove/properties_by_district_2019-03-02.csv')
#       2 london_df = london_df[(london_df['price'] != 'POA') & (london_df['price'] != 'Offers Invited') & (london_df['price'] != 'Coming Soon')]
# ----> 3 london_df['price'] = pd.to_numeric(london_df['price'])
#       4 london_df = london_df.reset_index(drop=True)
#       5 london_df['added/reduced_date'] = pd.to_datetime(london_df['added/reduced_date'], format='%d/%m/%Y')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Offers in Excess of
#
# 					450000" at position 1628

# %%
bermondsey_map = folium.Map(location=[51.4986, -0.0691],
                    zoom_start = 13)
for index, row in bermondsey_df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['address']).add_to(bermondsey_map)
    
london_map = folium.Map(location=[51.4986, -0.0691],
                    zoom_start = 10)
london_map.add_child(FastMarkerCluster(london_df[['latitude','longitude']].values.tolist()))
bermondsey_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fig, ax = plt.subplots(figsize=(16,9))

london_df.hist('price', ax=ax, bins=12)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

london_df.groupby('no_rooms')['no_rooms'].count().plot.bar(ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

london_df.groupby('no_rooms')['price'].mean().plot.bar(ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

london_df.groupby('property_type')['price'].mean().sort_values(ascending=False).plot.bar(ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

london_df['added/reduced_date'] = pd.to_datetime(london_df['added/reduced_date'])
df_added = london_df.set_index('added/reduced_date').resample('M')['price'].count().plot(ax=ax)

plt.show()

# %%
map_df = gpd.read_file(district_shape_file)
map_df = map_df.set_index('postdist')

district_df = district_links.set_index('district')

map_df = pd.concat([map_df, district_df], axis=1)

mean_district_price = london_df.groupby('district')['price'].mean()
mean_district_price_df = pd.DataFrame(mean_district_price)
mean_district_price_df = mean_district_price_df.reindex(district_list, fill_value=mean_district_price_df['price'].max())

map_df = pd.concat([map_df, mean_district_price_df], axis=1)
map_df = map_df[np.isfinite(map_df['price'])]

map_df['no_properties/population'] = map_df['no_properties']/map_df['pccnt']
map_df['no_properties/population'] = map_df['no_properties/population'].fillna(0)

# %%
fig, ax = plt.subplots(figsize=(16,9))

map_df.plot(ax=ax)

ax.set(title='districts')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

map_df[map_df.index != 'CR0'].plot(column='no_properties', cmap='Blues', ax=ax)

ax.set(title='no_properties_within_search')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

map_df.plot(column='price', cmap='Blues', ax=ax)

ax.set(title='district_average_property_price')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))

map_df.plot(column='no_properties/population', cmap='Blues', ax=ax)

ax.set(title='no_properties_in_search_vs_population_count')

plt.show()

# %%
map_df.sort_values(by='no_properties/population', ascending=False)
# Out:
#             id                                               geom  distid  \
# district
# CR7        438  SRID=27700;MULTIPOLYGON(((530152.535687331 167...   438.0
# RM19      2036  SRID=27700;MULTIPOLYGON(((553466.427112962 179...  2036.0
# SE25      2159  SRID=27700;MULTIPOLYGON(((532816.39125318 1679...  2159.0
# RM15      2032  SRID=27700;MULTIPOLYGON(((555856.826982332 182...  2032.0
# E13        651  SRID=27700;MULTIPOLYGON(((540340.322820255 183...   651.0
# RM6       2042  SRID=27700;MULTIPOLYGON(((546185.246634825 190...  2042.0
# CM14       396  SRID=27700;MULTIPOLYGON(((552529.375918822 195...   396.0
# TW16      2544  SRID=27700;MULTIPOLYGON(((509392.659123559 171...  2544.0
# RM13      2030  SRID=27700;MULTIPOLYGON(((549896.018833986 181...  2030.0
# DA16       504  SRID=27700;MULTIPOLYGON(((546458.050971477 177...   504.0
# CR3        434  SRID=27700;MULTIPOLYGON(((530437.048010746 155...   434.0
# SE20      2154  SRID=27700;MULTIPOLYGON(((534607.589552088 170...  2154.0
# RM3       2039  SRID=27700;MULTIPOLYGON(((552006.705005501 191...  2039.0
# DA17       505  SRID=27700;MULTIPOLYGON(((547857.4357218 17910...   505.0
# TW19      2547  SRID=27700;MULTIPOLYGON(((499686.968958277 175...  2547.0
# CR0        432  SRID=27700;MULTIPOLYGON(((528954.00062543 1673...   432.0
# SM1       2218  SRID=27700;MULTIPOLYGON(((525566.500781921 166...  2218.0
# UB7       2565  SRID=27700;MULTIPOLYGON(((503971.358303303 176...  2565.0
# SE28      2162  SRID=27700;MULTIPOLYGON(((544222.37791873 1794...  2162.0
# CR4        435  SRID=27700;MULTIPOLYGON(((526150.745811545 168...   435.0
# SE12      2145  SRID=27700;MULTIPOLYGON(((539481.385334987 175...  2145.0
# EN8        752  SRID=27700;MULTIPOLYGON(((535178.4198673 20487...   752.0
# SM2       2219  SRID=27700;MULTIPOLYGON(((523386.135599041 162...  2219.0
# TW13      2541  SRID=27700;MULTIPOLYGON(((508519.028939409 172...  2541.0
# DA15       503  SRID=27700;MULTIPOLYGON(((545197.974773518 174...   503.0
# RM8       2044  SRID=27700;MULTIPOLYGON(((546269.799736417 185...  2044.0
# UB4       2562  SRID=27700;MULTIPOLYGON(((509955.829777009 184...  2562.0
# RM1       2026  SRID=27700;MULTIPOLYGON(((551051.432226327 191...  2026.0
# RM7       2043  SRID=27700;MULTIPOLYGON(((549122.186869403 190...  2043.0
# EN3        747  SRID=27700;MULTIPOLYGON(((534681.193212537 195...   747.0
# ...        ...                                                ...     ...
# SW1A      2333  SRID=27700;MULTIPOLYGON(((528352.605868716 179...  2333.0
# SW1E      2334  SRID=27700;MULTIPOLYGON(((528900.028455462 179...  2334.0
# SW1H      2335  SRID=27700;MULTIPOLYGON(((529433.38496797 1796...  2335.0
# SW1P      2336  SRID=27700;MULTIPOLYGON(((529042.849403856 179...  2336.0
# SW1V      2337  SRID=27700;MULTIPOLYGON(((528900.028455462 179...  2337.0
# SW1W      2338  SRID=27700;MULTIPOLYGON(((527850.374461865 178...  2338.0
# SW1X      2339  SRID=27700;MULTIPOLYGON(((527580.167319459 179...  2339.0
# SW1Y      2340  SRID=27700;MULTIPOLYGON(((529203.669320633 180...  2340.0
# EC1A       666  SRID=27700;MULTIPOLYGON(((531474.928057092 181...   666.0
# SW3       2343  SRID=27700;MULTIPOLYGON(((526471.956901922 177...  2343.0
# SW5       2345  SRID=27700;MULTIPOLYGON(((525052.858210506 178...  2345.0
# SW7       2347  SRID=27700;MULTIPOLYGON(((525772.083135416 178...  2347.0
# EC1M       667  SRID=27700;MULTIPOLYGON(((531605.447374322 182...   667.0
# EC1R       669  SRID=27700;MULTIPOLYGON(((531259.550571009 182...   669.0
# W1F       2576  SRID=27700;MULTIPOLYGON(((529682.855781706 181...  2576.0
# N1C       1525  SRID=27700;MULTIPOLYGON(((530110.947599137 184...  1525.0
# TW6       2553  SRID=27700;MULTIPOLYGON(((504575.201843164 176...  2553.0
# EC1Y       671  SRID=27700;MULTIPOLYGON(((532052.91508534 1821...   671.0
# UB11      2559  SRID=27700;MULTIPOLYGON(((507253.26364929 1805...  2559.0
# EC2M       673  SRID=27700;MULTIPOLYGON(((532683.926101529 181...   673.0
# EC2N       674  SRID=27700;MULTIPOLYGON(((532838.793084191 181...   674.0
# EC4Y       688  SRID=27700;MULTIPOLYGON(((531105.054616096 181...   688.0
# EC4V       687  SRID=27700;MULTIPOLYGON(((531540.921526145 180...   687.0
# EC4R       686  SRID=27700;MULTIPOLYGON(((532445.454199302 180...   686.0
# EC4N       685  SRID=27700;MULTIPOLYGON(((532441.414119362 181...   685.0
# EC4M       684  SRID=27700;MULTIPOLYGON(((531681.804885179 181...   684.0
# W1B       2573  SRID=27700;MULTIPOLYGON(((528583.335658569 182...  2573.0
# W1C       2574  SRID=27700;MULTIPOLYGON(((528201.75423081 1810...  2574.0
# W1D       2575  SRID=27700;MULTIPOLYGON(((529044.407720404 181...  2575.0
# EC2V       676  SRID=27700;MULTIPOLYGON(((532113.442078883 181...   676.0
#
#          postarea distnum   pccnt  anomcnt    refpc         x         y  \
# district
# CR7            CR       7   581.0      3.0   CR77QB  531847.0  168431.0
# RM19           RM      19   145.0      1.0  RM191RR  555906.0  178461.0
# SE25           SE      25   661.0      1.0  SE255AJ  533910.0  168272.0
# RM15           RM      15   534.0      0.0  RM155HE  558090.0  181336.0
# E13             E      13   582.0      0.0   E130BE  540605.0  182956.0
# RM6            RM       6   526.0      0.0   RM65TX  547641.0  188561.0
# CM14           CM      14   653.0      1.0  CM144QP  558768.0  193598.0
# TW16           TW      16   537.0      0.0  TW166PY  510148.0  169727.0
# RM13           RM      13   583.0      0.0  RM138ST  552177.0  183099.0
# DA16           DA      16   557.0      0.0  DA163AT  546455.0  176119.0
# CR3            CR       3   781.0      0.0   CR36JH  533895.0  156050.0
# SE20           SE      20   498.0      1.0  SE208LJ  535049.0  169939.0
# RM3            RM       3   858.0      0.0   RM38NS  554150.0  191573.0
# DA17           DA      17   342.0      0.0  DA175BW  549263.0  178626.0
# TW19           TW      19   376.0      1.0  TW196AR  504122.0  174397.0
# CR0            CR       0  3222.0      1.0   CR05QL  533751.0  165533.0
# SM1            SM       1   938.0      1.0   SM14BF  525911.0  164589.0
# UB7            UB       7   603.0      0.0   UB77PS  506346.0  179430.0
# SE28           SE      28   453.0      0.0  SE288SN  546151.0  180238.0
# CR4            CR       4   898.0      0.0   CR41YG  528132.0  168862.0
# SE12           SE      12   496.0      0.0  SE129LS  540405.0  173617.0
# EN8            EN       8   951.0      0.0   EN88JL  536017.0  201791.0
# SM2            SM       2   575.0      0.0   SM26RD  525454.0  163017.0
# TW13           TW      13   718.0      0.0  TW137BE  510995.0  172324.0
# DA15           DA      15   529.0      0.0  DA158WW  545928.0  173454.0
# RM8            RM       8   561.0      0.0   RM83QU  547737.0  186435.0
# UB4            UB       4   688.0      0.0   UB40QS  510433.0  181844.0
# RM1            RM       1   488.0      0.0   RM14GS  551368.0  189425.0
# RM7            RM       7   612.0      1.0   RM79EU  550390.0  188393.0
# EN3            EN       3   994.0      0.0   EN35EE  535891.0  197560.0
# ...           ...     ...     ...      ...      ...       ...       ...
# SW1A           SW      1A   154.0      1.0  SW1A2AF  529916.0  180187.0
# SW1E           SW      1E    98.0      0.0  SW1E6DW  529214.0  179355.0
# SW1H           SW      1H    99.0      0.0  SW1H9LQ  529697.0  179475.0
# SW1P           SW      1P   487.0      0.0  SW1P2BE  529791.0  179022.0
# SW1V           SW      1V   588.0      0.0  SW1V2HB  529232.0  178412.0
# SW1W           SW      1W   354.0      0.0  SW1W9QQ  528468.0  178744.0
# SW1X           SW      1X   430.0      0.0  SW1X9EU  528057.0  179325.0
# SW1Y           SW      1Y   196.0      0.0  SW1Y4PD  529580.0  180417.0
# EC1A           EC      1A   118.0      1.0  EC1A9DS  531916.0  181674.0
# SW3            SW       3   910.0      2.0   SW33SX  527379.0  178366.0
# SW5            SW       5   304.0      1.0   SW59AN  525600.0  178552.0
# SW7            SW       7   708.0      2.0   SW75BD  526652.0  179089.0
# EC1M           EC      1M   199.0      0.0  EC1M4AJ  531736.0  181980.0
# EC1R           EC      1R   274.0      0.0  EC1R0LP  531294.0  182356.0
# W1F             W      1F   850.0      1.0   W1F7NZ  529407.0  181049.0
# N1C             N      1C    24.0      0.0   N1C4AA  530110.0  183496.0
# TW6            TW       6   209.0      0.0   TW61BP  507491.0  175752.0
# EC1Y           EC      1Y   197.0      1.0  EC1Y8SN  532467.0  182191.0
# UB11           UB      11    28.0      0.0  UB111FF  507978.0  180120.0
# EC2M           EC      2M   188.0      0.0  EC2M2AB  533094.0  181653.0
# EC2N           EC      2N    56.0      0.0  EC2N1AP  533013.0  181366.0
# EC4Y           EC      4Y   142.0      0.0  EC4Y7DN  531347.0  181014.0
# EC4V           EC      4V   136.0      2.0  EC4V5BT  531986.0  180962.0
# EC4R           EC      4R    81.0      0.0  EC4R0AX  532669.0  180820.0
# EC4N           EC      4N    67.0      1.0  EC4N8AF  532628.0  180958.0
# EC4M           EC      4M   105.0      0.0  EC4M8AD  532008.0  181196.0
# W1B             W      1B   331.0      3.0   W1B3BN  529059.0  181160.0
# W1C             W      1C   105.0      2.0   W1C2JF  528614.0  181121.0
# W1D             W      1D   709.0      4.0   W1D4QH  529685.0  181027.0
# EC2V           EC      2V   122.0      0.0  EC2V7HQ  532333.0  181380.0
#
#                   sprawl          locale  \
# district
# CR7               London  Thornton Heath
# RM19            Purfleet            None
# SE25              London   South Norwood
# RM15      South Ockendon            None
# E13               London        Plaistow
# RM6               London  Chadwell Heath
# CM14           Brentwood            None
# TW16             Sunbury            None
# RM13              London         Rainham
# DA16              London         Welling
# CR3             Caterham            None
# SE20              London           Penge
# RM3               London     Harold Wood
# DA17              London           Erith
# TW19            Stanwell            None
# CR0               London         Croydon
# SM1               London          Sutton
# UB7               London    West Drayton
# SE28              London      Thamesmead
# CR4               London         Mitcham
# SE12              London         Catford
# EN8             Cheshunt            None
# SM2               London          Sutton
# TW13              London         Feltham
# DA15              London        Blackfen
# RM8               London        Dagenham
# UB4               London           Hayes
# RM1               London         Romford
# RM7               London         Romford
# EN3               London         Enfield
# ...                  ...             ...
# SW1A              London  Central London
# SW1E              London        Victoria
# SW1H              London        Victoria
# SW1P              London        Victoria
# SW1V              London        Victoria
# SW1W              London        Victoria
# SW1X              London   Knightsbridge
# SW1Y              London  Central London
# EC1A              London  City of London
# SW3               London         Chelsea
# SW5               London      Kensington
# SW7               London      Kensington
# EC1M              London        Finsbury
# EC1R              London        Finsbury
# W1F               London  Central London
# N1C               London          Camden
# TW6             Stanwell            None
# EC1Y              London          Hoxton
# UB11              London           Hayes
# EC2M              London  City of London
# EC2N              London  City of London
# EC4Y              London  Central London
# EC4V              London  City of London
# EC4R              London  City of London
# EC4N              London  City of London
# EC4M              London  City of London
# W1B               London  Central London
# W1C               London  Central London
# W1D               London  Central London
# EC2V              London  City of London
#
#                                                    geometry  no_properties  \
# district
# CR7       POLYGON ((-0.1306662542408503 51.3936967619069...            184
# RM19      (POLYGON ((0.2091011690564324 51.4898576161776...             45
# SE25      POLYGON ((-0.09233293679568312 51.394702108068...            192
# RM15      POLYGON ((0.244962219329849 51.51888416316647,...            143
# E13       POLYGON ((0.02209935483323225 51.5368882735124...            150
# RM6       POLYGON ((0.1089964091582635 51.59340419394296...            130
# CM14      (POLYGON ((0.2026441966425453 51.6357864368001...            157
# TW16      POLYGON ((-0.4278532742795984 51.4292524095355...            125
# RM13      (POLYGON ((0.1587280519455698 51.5122849964670...            133
# DA16      POLYGON ((0.1074910785285113 51.47570374698206...            126
# CR3       POLYGON ((-0.1310167937339426 51.2846620244364...            168
# SE20      POLYGON ((-0.06557217965747394 51.418701513922...            103
# RM3       POLYGON ((0.193518638515745 51.60320031204628,...            177
# DA17      (POLYGON ((0.1283803757021512 51.4915371517021...             70
# TW19      POLYGON ((-0.5660868792863679 51.4734111374252...             76
# CR0       POLYGON ((-0.1480381856383222 51.3901384305319...            650
# SM1       POLYGON ((-0.197096462588208 51.38075198042985...            187
# UB7       POLYGON ((-0.5042169348536956 51.4789073912368...            120
# SE28      (POLYGON ((0.07621171659704525 51.495866938035...             90
# CR4       POLYGON ((-0.1877347511713224 51.4052034212720...            175
# SE12      POLYGON ((0.006274820878671952 51.458649019357...             96
# EN8       POLYGON ((-0.0442035748115133 51.7262930959188...            183
# SM2       POLYGON ((-0.2295958071633542 51.3505007226105...            109
# TW13      POLYGON ((-0.4400078442275667 51.4413690630844...            136
# DA15      POLYGON ((0.0880386767913315 51.44709123860519...            100
# RM8       POLYGON ((0.1083106503419776 51.55222316351584...            105
# UB4       POLYGON ((-0.4157339317930338 51.5453345080014...            128
# RM1       POLYGON ((0.1797179539332132 51.60308723148007...             90
# RM7       POLYGON ((0.1511975832444808 51.58912445009421...            112
# EN3       POLYGON ((-0.05497149899718138 51.643119418197...            178
# ...                                                     ...            ...
# SW1A      POLYGON ((-0.1521358683270667 51.5028933780380...              0
# SW1E      POLYGON ((-0.1445218781868073 51.4961551237958...              0
# SW1H      POLYGON ((-0.1366552627657464 51.5006359499538...              0
# SW1P      POLYGON ((-0.1424619139887998 51.4962140307395...              0
# SW1V      (POLYGON ((-0.1445218781868073 51.496155123795...              0
# SW1W      (POLYGON ((-0.1597945939683723 51.492411971758...              0
# SW1X      POLYGON ((-0.1633885325653144 51.4998389776111...              0
# SW1Y      POLYGON ((-0.139676322656717 51.50772510710747...              0
# EC1A      POLYGON ((-0.1065387110031681 51.5175665303462...              0
# SW3       POLYGON ((-0.179900083881447 51.48616435962381...              0
# SW5       POLYGON ((-0.2000504294771529 51.4935157353389...              0
# SW7       POLYGON ((-0.1896328177453464 51.4949460520344...              0
# EC1M      (POLYGON ((-0.1044370777085877 51.522874691308...              0
# EC1R      POLYGON ((-0.1092553159762982 51.5269283542749...              0
# W1F       POLYGON ((-0.1325447262824889 51.5132613218757...              0
# N1C       POLYGON ((-0.1252310571042964 51.5411193352052...              0
# TW6       POLYGON ((-0.4955311185873612 51.4786065146458...              0
# EC1Y      POLYGON ((-0.09796985199393787 51.523280539317...              0
# UB11      POLYGON ((-0.4557648027509177 51.5141531249905...              0
# EC2M      (POLYGON ((-0.08912036061385509 51.51738689119...              0
# EC2N      POLYGON ((-0.08691701045503653 51.516699199272...              0
# EC4Y      POLYGON ((-0.1120307707926629 51.5136753849128...              0
# EC4V      POLYGON ((-0.1058660201546263 51.5108532852686...              0
# EC4R      POLYGON ((-0.09278941359658081 51.511836498559...              0
# EC4N      POLYGON ((-0.09280840321618784 51.512775901694...              0
# EC4M      POLYGON ((-0.1036526753143058 51.5152606348932...              0
# W1B       (POLYGON ((-0.1479758829063604 51.523497034500...              0
# W1C       POLYGON ((-0.1538504348278653 51.5142502024024...              0
# W1D       POLYGON ((-0.1416544658719192 51.5155121734467...              0
# EC2V      POLYGON ((-0.09744555235282154 51.514925743414...              0
#
#                                                        link            code  \
# district
# CR7       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E529
# RM19      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2197
# SE25      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2326
# RM15      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2193
# E13       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E748
# RM6       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2204
# CM14      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E487
# TW16      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2720
# RM13      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2191
# DA16      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E596
# CR3       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E525
# SE20      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2321
# RM3       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2200
# DA17      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E597
# TW19      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2723
# CR0       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E523
# SM1       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2385
# UB7       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2741
# SE28      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2329
# CR4       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E526
# SE12      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2312
# EN8       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E858
# SM2       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2386
# TW13      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2717
# DA15      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E595
# RM8       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2206
# UB4       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2738
# RM1       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2187
# RM7       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2205
# EN3       https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E853
# ...                                                     ...             ...
# SW1A      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2506
# SW1E      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2507
# SW1H      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2508
# SW1P      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2509
# SW1V      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2510
# SW1W      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2511
# SW1X      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2512
# SW1Y      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2513
# EC1A      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E765
# SW3       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2516
# SW5       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2518
# SW7       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2520
# EC1M      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E766
# EC1R      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E769
# W1F       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2753
# N1C       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E6147
# TW6       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2729
# EC1Y      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E771
# UB11      https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2735
# EC2M      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E773
# EC2N      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E774
# EC4Y      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E791
# EC4V      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E790
# EC4R      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E789
# EC4N      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E787
# EC4M      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E786
# W1B       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2750
# W1C       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2751
# W1D       https://www.rightmove.co.uk/property-for-sale/...  OUTCODE%5E2752
# EC2V      https://www.rightmove.co.uk/property-for-sale/...   OUTCODE%5E777
#
#                   price  no_properties/population
# district
# CR7       353228.286517                  0.316695
# RM19      258397.500000                  0.310345
# SE25      346850.823529                  0.290469
# RM15      327338.251748                  0.267790
# E13       359027.176056                  0.257732
# RM6       344285.317460                  0.247148
# CM14      344200.100671                  0.240429
# TW16      345273.333333                  0.232775
# RM13      344349.593496                  0.228130
# DA16      379910.213675                  0.226212
# CR3       341307.362963                  0.215109
# SE20      370554.245283                  0.206827
# RM3       345532.283237                  0.206294
# DA17      322532.859155                  0.204678
# TW19      343621.458333                  0.202128
# CR0       450000.000000                  0.201738
# SM1       337289.201183                  0.199360
# UB7       370954.500000                  0.199005
# SE28      312918.369565                  0.198675
# CR4       363261.976048                  0.194878
# SE12      343548.842105                  0.193548
# EN8       344863.534483                  0.192429
# SM2       339470.297030                  0.189565
# TW13      351952.909774                  0.189415
# DA15      351680.206186                  0.189036
# RM8       329673.118812                  0.187166
# UB4       360635.539062                  0.186047
# RM1       346929.352941                  0.184426
# RM7       348296.621622                  0.183007
# EN3       351522.134831                  0.179074
# ...                 ...                       ...
# SW1A      450000.000000                  0.000000
# SW1E      450000.000000                  0.000000
# SW1H      450000.000000                  0.000000
# SW1P      450000.000000                  0.000000
# SW1V      450000.000000                  0.000000
# SW1W      450000.000000                  0.000000
# SW1X      450000.000000                  0.000000
# SW1Y      450000.000000                  0.000000
# EC1A      450000.000000                  0.000000
# SW3       450000.000000                  0.000000
# SW5       450000.000000                  0.000000
# SW7       450000.000000                  0.000000
# EC1M      450000.000000                  0.000000
# EC1R      450000.000000                  0.000000
# W1F       450000.000000                  0.000000
# N1C       450000.000000                  0.000000
# TW6       450000.000000                  0.000000
# EC1Y      450000.000000                  0.000000
# UB11      450000.000000                  0.000000
# EC2M      450000.000000                  0.000000
# EC2N      450000.000000                  0.000000
# EC4Y      450000.000000                  0.000000
# EC4V      450000.000000                  0.000000
# EC4R      450000.000000                  0.000000
# EC4N      450000.000000                  0.000000
# EC4M      450000.000000                  0.000000
# W1B       450000.000000                  0.000000
# W1C       450000.000000                  0.000000
# W1D       450000.000000                  0.000000
# EC2V      450000.000000                  0.000000
#
# [298 rows x 18 columns]

# %%
london_df.groupby('district')['district'].count().sort_values(ascending=False)
# Out:
# district
# SW16    252
# DA1     214
# SE18    201
# SE25    197
# CR7     190
# RM3     186
# EN8     182
# EN3     181
# SM1     176
# CR4     173
# CR2     171
# WD6     167
# SE9     156
# NW10    155
# EN1     153
# HA1     153
# BR1     153
# E17     151
# E13     151
# CM14    151
# BR2     150
# BR5     149
# IG11    147
# RM15    145
# UB5     140
# HA3     140
# SL3     139
# TW13    138
# CR3     138
# RM13    134
#        ...
# DA6      15
# SW14     15
# E1W      14
# IG5      13
# SW12     13
# TW9      13
# RM4      13
# W6       12
# SE11     12
# NW11     12
# W9       11
# N6       10
# SE24      7
# NW8       7
# N5        7
# E8        6
# DA18      6
# SW6       6
# TW10      6
# NW5       5
# W14       3
# NW3       3
# W2        3
# W11       3
# W10       3
# SW13      3
# SW10      2
# IG4       2
# EC2A      2
# EC1V      1
# Name: district, Length: 234, dtype: int64
