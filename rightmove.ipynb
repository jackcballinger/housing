# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
import time
import datetime
import glob
import os
import create_schroders_cert
import json


def timer(wait_time):
    print("waiting for timer: " + str(wait_time) + "s")
    time.sleep(wait_time)

def import_previous_file():
    list_of_files = glob.glob('C:/Users/ballinj/housing/data/rightmove/*.csv')
    latest_file = max(list_of_files, key=os.path.getctime)
    combined_df_old = pd.read_csv(latest_file, index_col=0)
    return combined_df_old

def import_previous_sales_file():
    list_of_files = glob.glob('C:/Users/ballinj/housing/data/rightmove/sales/*.csv')
    latest_file = max(list_of_files, key=os.path.getctime)
    combined_sales_df_old = pd.read_csv(latest_file, index_col=0)
    return combined_sales_df_old

def get_soup(url, params=None):
    cert = "C:/Users/ballinj/housing/ca-certificates.crt"
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36'}
    r = requests.get(url, params=params, verify=cert, headers=headers)
    c = r.content    
    soup = BeautifulSoup(c, 'html.parser')
    return(soup)

def get_no_results(soup):
    no_results = soup.find('span', attrs={'class':'searchHeader-resultCount'}).text.strip()
    return no_results

def get_listing_df(no_results):
    index_array = np.arange(0,int(no_results)+24,24).tolist()
    listing_ids, links, property_types, addresses, prices_per_month, prices_per_week, featured_properties = [],[],[],[],[],[],[]
    for index in index_array:
        url = 'https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E85212&maxBedrooms=2&minBedrooms=1&maxPrice=1750&index=' + str(index) + '&includeLetAgreed=false'
        soup = get_soup(url)
        main_data = soup.find('div', attrs={'class':'main'})
        search_results = soup.find('div', attrs={'class':'l-searchResults'})
        ids = search_results.findAll('a', attrs={'class':'propertyCard-anchor'})#['id']
        for id in ids:
            listing_ids.append(id['id'][4:])

        listing_data = search_results.findAll('div', attrs={'class':'propertyCard-wrapper'})

        for listing in listing_data:
            listing.find('')
            featured_properties.append(listing.find('div', attrs={'class':'propertyCard-moreInfoFeaturedTitle'}).text.strip())

            details = listing.find('div', attrs={'class':'propertyCard-details'})
            addresses.append(listing.find('address').text.strip())
            property_types.append(listing.find('h2').text.strip())
            links.append('https://www.rightmove.co.uk/' + details.find('a')['href'])

            pricing = listing.find('div', attrs={'class':'propertyCard-price'})
            prices_per_month.append(pricing.find('div', attrs={'class':'propertyCard-rentalPrice-primary'}).text.strip())
    listing_df = pd.DataFrame(listing_ids, columns=['listing_id'])
    listing_df['address'] = addresses
    listing_df['property_type'] = property_types
    listing_df['property_link'] = links
    listing_df['price_per_month'] = prices_per_month
    listing_df['featured_property'] = featured_properties
    listing_df = listing_df[~listing_df['property_type'].str.contains('share')]
    listing_df = listing_df[~listing_df['property_type'].str.contains('Parking')]
    listing_df = listing_df[listing_df['address']!=""]
    listing_df = listing_df[listing_df['featured_property']==""]
    listing_df = listing_df.reset_index(drop=True)
    return listing_df

def get_sale_listing_df(no_results):
    index_array = np.arange(0,int(no_results)+24,24).tolist()
    listing_ids, links, property_types, addresses, prices, prices_per_week, featured_properties = [],[],[],[],[],[],[]
    added_reduced_array, letting_agent_name, letting_agent_number, num_pictures = [],[],[],[]
    for index in index_array:
        url = 'https://www.rightmove.co.uk/property-for-sale/find.html?minBedrooms=1&keywords=&sortType=6&minPrice=200000&viewType=LIST&channel=BUY&index=' + str(index) + '&maxPrice=500000&radius=0.0&locationIdentifier=REGION%5E85212'
        soup = get_soup(url)
        main_data = soup.find('div', attrs={'class':'main'})
        search_results = soup.find('div', attrs={'class':'l-searchResults'})
        ids = search_results.findAll('a', attrs={'class':'propertyCard-anchor'})#['id']
        for id in ids:
            listing_ids.append(id['id'][4:])

        listing_data = search_results.findAll('div', attrs={'class':'propertyCard-wrapper'})

        for listing in listing_data:
            featured_properties.append(listing.find('div', attrs={'class':'propertyCard-moreInfoFeaturedTitle'}).text.strip())

            details = listing.find('div', attrs={'class':'propertyCard-details'})
            addresses.append(listing.find('address').text.strip())
            property_types.append(listing.find('h2').text.strip())
            links.append('https://www.rightmove.co.uk/' + details.find('a')['href'])

            pricing = listing.find('div', attrs={'class':'propertyCard-price'})
            prices.append(pricing.find('div', attrs={'class':'propertyCard-priceValue'}).text.strip())
            added_reduced_array.append(listing.find('div', attrs={'class':'propertyCard-branchSummary'}).find('span', attrs={'class':'propertyCard-branchSummary-addedOrReduced'}).text.strip())
            estate_agent = listing.find('div', attrs={'class':'propertyCard-branchSummary'}).find('span', attrs={'class':'propertyCard-branchSummary-branchName'}).text.strip()
            estate_agent = estate_agent[estate_agent.find('by')+3:].strip()
            letting_agent_name.append(estate_agent)
            letting_agent_number.append(listing.find('div', attrs={'class':'propertyCard-contacts'}).find('a', attrs={'class':'propertyCard-contactsPhoneNumber'}).text.strip())
            meta_data = listing.find('div', attrs={'class':'propertyCard-moreInfoMeta'})
            num_pictures.append(meta_data.find('span', attrs={'class':'propertyCard-moreInfoNumber'}).text.strip())
    listing_df = pd.DataFrame(listing_ids, columns=['listing_id'])
    listing_df['address'] = addresses
    listing_df['property_type'] = property_types
    listing_df['property_link'] = links
    listing_df['price'] = prices
    listing_df['added/reduced_date'] = added_reduced_array
    listing_df['agent_name'] = letting_agent_name
    listing_df['agent_number'] = letting_agent_number
    listing_df['no_pictures'] = num_pictures
    listing_df['featured_property'] = featured_properties
    listing_df = listing_df[~listing_df['property_type'].str.contains('share')]
    listing_df = listing_df[~listing_df['property_type'].str.contains('Parking')]
    listing_df = listing_df[listing_df['address']!=""]
    listing_df = listing_df[listing_df['featured_property']==""]
    listing_df = listing_df.reset_index(drop=True)
    return listing_df

def get_property_coordinates(url, listing_df):
    latitudes, longitudes = [],[]
    map_url = url.replace('find','map')
    map_url = map_url.replace('LIST','MAP')
    soup = get_soup(map_url)
    scripts = soup.findAll('script')
    script_list = [script if 'window.jsonModel' in str(script) else '' for script in scripts]
    script_list = [script for script in script_list if script != '']
    script = str(script_list[0])
    script = script[script.find('{'):script.rfind('}')+1]
    properties_json = json.loads(script)
    property_id, coordinates = [],[]
    for row in properties_json['properties']:
        property_id.append(str(row['id']))
        coordinates.append([row['location']['latitude'], row['location']['longitude']])
    coordinates_dict = dict(zip(property_id, coordinates))
    for id in list(listing_df['listing_id']):
        latitudes.append(coordinates_dict[str(id)][0])
        longitudes.append(coordinates_dict[str(id)][1])
    listing_df['latitude'] = latitudes
    listing_df['longitude'] = longitudes
    return listing_df

def format_df(sales_listing_df):
    initial_scraped_dates = []
    sales_listing_df['property_type'] = sales_listing_df['property_type'].map(lambda x: x.rstrip(' for sale'))
    df = pd.DataFrame(sales_listing_df['property_type'].str.split('bedroom',1).tolist(), columns=['no_rooms','property_types'])
    df['property_types'] = df['property_types'].str.replace('hou','house')
    df['no_rooms'] = pd.to_numeric(df['no_rooms'])
    sales_listing_df = pd.concat([sales_listing_df, df], axis=1)
    sales_listing_df = sales_listing_df.drop(columns=['property_type'])
    sales_listing_df['added/reduced_date'] = sales_listing_df['added/reduced_date'].str.replace(' yesterday',' on ' + yesterday)
    sales_listing_df['added/reduced_date'] = sales_listing_df['added/reduced_date'].str.replace(' today',' on ' + today_2)
    df = pd.DataFrame(sales_listing_df['added/reduced_date'].str.split('on',1).tolist(), columns=['reduced/added','date_reduced/added'])
    sales_listing_df = pd.concat([sales_listing_df, df], axis=1)
    sales_listing_df = sales_listing_df[['listing_id', 'address', 'no_rooms','price','property_types','property_link','reduced/added', 'date_reduced/added',
                                         'no_pictures','latitude','longitude', 'agent_name','agent_number']]
    sales_listing_df['date_reduced/added'] = pd.to_datetime(sales_listing_df['date_reduced/added'])
    sales_listing_df['no_pictures'] = pd.to_numeric(sales_listing_df['no_pictures'])
    sales_listing_df['most_recent_scrape_date'] = datetime.datetime.today().date().strftime('%d/%m/%Y')
    most_recent_scraped_dates = today
    for index, row in sales_listing_df.iterrows():
        if int(row['listing_id']) not in sales_listing_df_old['listing_id'].tolist():
            initial_scraped_dates.append(today)
        else:
            initial_scraped_dates.append(sales_listing_df_old[sales_listing_df_old['listing_id']==int(row['listing_id'])]['initial_scrape_date'].tolist()[0])
    sales_listing_df['initial_scrape_date'] = initial_scraped_dates
    return sales_listing_df

def get_details_df(listing_df):
    dates_available, furnishings, letting_types, added_array, reduced_array, descriptions, nearest_stations_array, nearest_stations_dict = [],[],[],[],[],[],[],[]
    initial_scraped_dates, most_recent_scraped_dates, longitudes, latitudes, agent_name, agent_address, agent_numbers = [],[],[],[],[],[],[]
    for index, row in listing_df.iterrows():
        url = row['property_link']#'https://www.rightmove.co.uk/property-to-rent/property-68955643.html'
        print(url)
        print(str(index + 1) + ' out of ' + str(len(listing_df)))
        timer(2)
        #     print(url)
        soup = get_soup(url)

        listing_details = soup.find('div', attrs={'id':'primaryContent'})
        listing_primary_details = listing_details.find('div', attrs={'id':'detailsTabs'})
        description_tab = listing_primary_details.find('div', attrs={'id':'description'})

        #letting information
        letting_information = description_tab.find('tbody')
        letting_information_rows = letting_information.findAll('tr')
        letting_information_array = [row.text.strip().split(':') for row in letting_information_rows]
        for letting_row in letting_information_array:
            letting_row[1] = letting_row[1].strip()
        letting_information_dict = {item[0]: item[1] for item in letting_information_array}

        if 'Letting type' in letting_information_dict.keys():
            letting_types.append(letting_information_dict['Letting type'])
        else:
            letting_types.append(None)

        if 'Furnishing' in letting_information_dict.keys():
            furnishings.append(letting_information_dict['Furnishing'])
        else:
            furnishings.append(None)

        if 'Date available' in letting_information_dict.keys():
            dates_available.append(letting_information_dict['Date available'])
        else:
            dates_available.append(None)

        if 'Added on Rightmove' in letting_information_dict.keys():
            added_array.append(letting_information_dict['Added on Rightmove'])
        else:
            added_array.append(None)

        if 'Reduced on Rightmove' in letting_information_dict.keys():
            reduced_array.append(letting_information_dict['Reduced on Rightmove'])
        else:
            reduced_array.append(None)

        # description
        descriptions.append(description_tab.find('p', attrs={'itemprop':'description'}).text.strip().replace('''\r''',''))

        # nearest stations
        try:
            nearest_stations = soup.find('ul', attrs={'class':'stations-list'})
            station_rows = nearest_stations.findAll('li')
            station_array = [row.text.strip().split('\n') for row in station_rows]
            station_dict = {item[0]: item[1] for item in station_array}
            nearest_stations_array.append(station_array)
            nearest_stations_dict.append(station_dict)
        except AttributeError:
            nearest_stations_array.append([None])
            nearest_stations_dict.append({None})
        
        maps_section = soup.find('a', attrs={'class':'block js-tab-trigger js-ga-minimap'})
        long_lat_href = maps_section.find('img')['src']
        latitudes.append(str(long_lat_href)[str(long_lat_href).find('latitude') + len('latitude='):str(long_lat_href).find('&')])
        longitudes.append(str(long_lat_href)[str(long_lat_href).find('longitude') + len('longitude='):str(long_lat_href).find('&z')])
        
        most_recent_scraped_dates = today
        if int(row['listing_id']) not in combined_df_old['listing_id'].tolist():
            initial_scraped_dates.append(today)
        else:
            initial_scraped_dates.append(combined_df_old[combined_df_old['listing_id']==int(row['listing_id'])]['initial_scrape_date'].tolist()[0])
        
        secondary_details = soup.find('div', attrs={'id':'secondaryAgentDetails'})
        request_details = soup.find('div', attrs={'id':'requestdetails'})
        agent_details = secondary_details.find('div', attrs={'class':'agent-details-display'}).find('div', attrs={'class':'overflow-hidden'}).text.strip()
        agent_details = agent_details.split('\n')
        agent_details = [row.replace('\r',"").strip() for row in agent_details]
        agent_name.append(agent_details[0])
        agent_address.append(", ".join(agent_details[1:]))
        try:
            agent_number = request_details.find('p').find('a')['href']
            agent_number = agent_number[agent_number.find(':')+1:].strip()
            agent_numbers.append(agent_number)
        except AttributeError:
            agent_numbers.append('na')
        
    details_df = pd.DataFrame(dates_available, columns=['dates_available'])
    details_df['furnishing'] = furnishings
    details_df['letting_type'] = letting_types
    details_df['letting_agent'] = agent_name
    details_df['letting_agent_address'] = agent_address
    details_df['letting_agent_number'] = agent_numbers
    details_df['date_added'] = added_array
    details_df['date_reduced'] = reduced_array
    details_df['description'] = descriptions
    details_df['longitude'] = longitudes
    details_df['latitude'] = latitudes
    details_df['initial_scrape_date'] = initial_scraped_dates
    details_df['most_recent_scrape_date'] = most_recent_scraped_dates
    return details_df, nearest_stations_array, nearest_stations_dict

def get_station_df(nearest_stations_array, nearest_stations_dict, all_stations_manual):
    station_array = []
    for property in nearest_stations_array:
        station_array_temp_mid = []
        for row in property:
            station_array_temp_small = []
            for station in all_stations_manual:
                try:
                    if row[0] == station:
                        station_array_temp_small.append(row[0])
                    else:
                        station_array_temp_small.append(None)
                except:
                    continue
            station_array_temp_mid.append(station_array_temp_small)
        station_array.append(station_array_temp_mid)

    stations_sparse_array = []
    for location in station_array:
        combined_station_array = []
        for a,b,c in zip(location[0],location[1],location[2]):
            if a != None:
                combined_station_array.append(a)
            elif b != None:
                combined_station_array.append(b)
            elif c != None:
                combined_station_array.append(c)
            else:
                combined_station_array.append(None)
        stations_sparse_array.append(combined_station_array)

    distances_sparse_array = []
    dict_counter = 0
    for location in stations_sparse_array:
        distances = []
        for datapoint in location:
            if datapoint in nearest_stations_dict[dict_counter].keys():
                distances.append(nearest_stations_dict[dict_counter][datapoint].replace('(',"").replace(')',""))
            else:
                distances.append(None)
        distances_sparse_array.append(distances)
        dict_counter = dict_counter + 1
    stations_df = pd.DataFrame(distances_sparse_array, columns=all_stations_manual)
    return stations_df

def update_stations(all_stations_list, listing_df):
    for index, row in listing_df.iterrows():
        url = row['property_link']
        print(url)
        print(str(index + 1) + ' out of ' + str(len(listing_df)))
        timer(2)
        soup = get_soup(url)   
        nearest_stations = soup.find('ul', attrs={'class':'stations-list'})
        station_rows = nearest_stations.findAll('li')
        station_array = [row.text.strip().split('\n') for row in station_rows]
        for item in station_array:
            if item[0] not in all_stations:
                all_stations.append(item[0])
    return all_stations

today = datetime.datetime.today().strftime("%d-%m-%Y")
yesterday = datetime.datetime.today().date() - datetime.timedelta(1)
yesterday = yesterday.strftime('%d/%m/%Y')
today_2 = datetime.datetime.today().date()
today_2 = today_2.strftime('%d/%m/%Y')

soup = get_soup('https://www.rightmove.co.uk/property-to-rent/find.html?locationIdentifier=REGION%5E85212&maxBedrooms=2&minBedrooms=1&maxPrice=1750&propertyTypes=detached%2Csemi-detached%2Cterraced%2Cflat&secondaryDisplayPropertyType=housesandflats&includeLetAgreed=false')
combined_df_old = import_previous_file()
no_results = get_no_results(soup)
listing_df = get_listing_df(no_results)
details_df, nearest_stations_array, nearest_stations_dict = get_details_df(listing_df)

all_stations_manual = ['Bermondsey',
                       'Borough',
                       'Canada Water',
                       'Elephant & Castle',
                       'Elephant & Castle (Bakerloo)',
                       'Elephant & Castle (Northern)',
                       'London Bridge',
                       'Monument',
                       'Queens Road Peckham',
                       'Rotherhithe',
                       'South Bermondsey',
                       'Southwark',
                       'Surrey Quays',
                       'Tower Gateway',
                       'Tower Hill',
                       'Wapping']

station_df = get_station_df(nearest_stations_array, nearest_stations_dict, all_stations_manual)
combined_df = pd.concat([listing_df, details_df, station_df], axis=1)
for index, row in combined_df_old.iterrows():
    if int(row['listing_id']) not in [int(id) for id in combined_df['listing_id'].tolist()]:
        combined_df = combined_df.append(row)
combined_df = combined_df.reset_index(drop=True)
combined_df.to_csv('C:/Users/ballinj/housing/data/rightmove/housing_data_{}.csv'.format(today))
print('rental data done')

# for sale properties
print('working on sale data')
url = 'https://www.rightmove.co.uk/property-for-sale/find.html?minBedrooms=1&keywords=&sortType=6&minPrice=200000&viewType=LIST&channel=BUY&index=0&maxPrice=500000&radius=0.0&locationIdentifier=REGION%5E85212'
soup = get_soup(url)
sales_listing_df_old = import_previous_sales_file()
no_results = get_no_results(soup)
sales_listing_df = get_sale_listing_df(no_results)
sales_listing_df = get_property_coordinates(url, sales_listing_df)
sales_listing_df = format_df(sales_listing_df)
for index, row in sales_listing_df_old.iterrows():
    if int(row['listing_id']) not in [int(id) for id in sales_listing_df['listing_id'].tolist()]:
        sales_listing_df = sales_listing_df.append(row)
sales_listing_df = sales_listing_df.reset_index(drop=True)
sales_listing_df.to_csv('C:/Users/ballinj/housing/data/rightmove/sales/housing_data_{}.csv'.format(today))
print('sale data done')
# Out:
# https://www.rightmove.co.uk//property-to-rent/property-70229692.html
# 1 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79566068.html
# 2 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79221683.html
# 3 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59832693.html
# 4 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79041245.html
# 5 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70219960.html
# 6 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70193752.html
# 7 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70191274.html
# 8 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70189843.html
# 9 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70189777.html
# 10 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60427119.html
# 11 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60426030.html
# 12 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60424836.html
# 13 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60422514.html
# 14 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78829613.html
# 15 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60417198.html
# 16 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70173460.html
# 17 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70153039.html
# 18 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60396942.html
# 19 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79105388.html
# 20 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60385209.html
# 21 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70137217.html
# 22 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70136872.html
# 23 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60383352.html
# 24 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70128055.html
# 25 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70119730.html
# 26 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60344286.html
# 27 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79515365.html
# 28 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60322299.html
# 29 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70232995.html
# 30 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60303561.html
# 31 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79481930.html
# 32 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59894490.html
# 33 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79471331.html
# 34 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79458098.html
# 35 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70057294.html
# 36 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-58750755.html
# 37 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69832615.html
# 38 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77165240.html
# 39 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70075498.html
# 40 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60232380.html
# 41 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79421093.html
# 42 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79420484.html
# 43 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60225903.html
# 44 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60209775.html
# 45 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79399262.html
# 46 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-48270118.html
# 47 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-45626951.html
# 48 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79386836.html
# 49 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57101160.html
# 50 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70009408.html
# 51 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60181794.html
# 52 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-66266974.html
# 53 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79367600.html
# 54 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60172905.html
# 55 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60171609.html
# 56 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78714245.html
# 57 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79019039.html
# 58 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-58097046.html
# 59 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69969979.html
# 60 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79258109.html
# 61 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69940978.html
# 62 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78277256.html
# 63 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69923437.html
# 64 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69922825.html
# 65 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77702183.html
# 66 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78651008.html
# 67 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69398224.html
# 68 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59751627.html
# 69 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69739522.html
# 70 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78858011.html
# 71 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79061720.html
# 72 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59656977.html
# 73 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59947677.html
# 74 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69089485.html
# 75 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69847009.html
# 76 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79046642.html
# 77 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69834280.html
# 78 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79042664.html
# 79 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59440899.html
# 80 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59295846.html
# 81 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79053617.html
# 82 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78327140.html
# 83 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69799378.html
# 84 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78988214.html
# 85 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59864454.html
# 86 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-32571016.html
# 87 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69774280.html
# 88 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69761329.html
# 89 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69894154.html
# 90 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59804598.html
# 91 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-55696455.html
# 92 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59748777.html
# 93 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78879107.html
# 94 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59744844.html
# 95 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69669340.html
# 96 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59254257.html
# 97 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59723868.html
# 98 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69477637.html
# 99 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78827858.html
# 100 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77781056.html
# 101 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78773960.html
# 102 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78760598.html
# 103 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78750659.html
# 104 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78711524.html
# 105 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59616906.html
# 106 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69366568.html
# 107 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70016296.html
# 108 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69504640.html
# 109 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69502627.html
# 110 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-70233070.html
# 111 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59543031.html
# 112 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-63729958.html
# 113 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69437068.html
# 114 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59464587.html
# 115 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59450460.html
# 116 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69357784.html
# 117 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59415279.html
# 118 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59374323.html
# 119 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69320917.html
# 120 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78380813.html
# 121 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-79053725.html
# 122 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78296570.html
# 123 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-78277187.html
# 124 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-59256714.html
# 125 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77254505.html
# 126 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57472077.html
# 127 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77701745.html
# 128 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77613461.html
# 129 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-77605586.html
# 130 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-58496973.html
# 131 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57739470.html
# 132 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-58119879.html
# 133 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60199488.html
# 134 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-76919864.html
# 135 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-76665872.html
# 136 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57049848.html
# 137 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-76076540.html
# 138 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57177531.html
# 139 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-67914493.html
# 140 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-69803110.html
# 141 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-75232457.html
# 142 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-61777870.html
# 143 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-60754540.html
# 144 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-66757102.html
# 145 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-73402484.html
# 146 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-56655105.html
# 147 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-57152463.html
# 148 out of 149
# waiting for timer: 2s
# https://www.rightmove.co.uk//property-to-rent/property-65518145.html
# 149 out of 149
# waiting for timer: 2s
# rental data done
# working on sale data
# sale data done

# %%
sales_listing_df
# Out:
#     listing_id                                            address  no_rooms  \
# 0     70228570               Stubbs Drive, South Bermondsey, SE16         2
# 1     69215737                 Great Suffolk Street, Borough, SE1         1
# 2     69681757                   Mandeville House, Bermondsey SE1         3
# 3     79549748                         Concorde Way, London, SE16         1
# 4     75545393                          Henley Drive, London, SE1         1
# 5     59423931                           Stubbs Drive, Bermondsey         1
# 6     60422916                       Brodie House, Bermondsey SE1         3
# 7     54725169                             Old Kent Road, Borough         3
# 8     56764827            118 Southwark Bridge Road, Borough, SE1         1
# 9     60363642                     Neckinger Estate, London, SE16         2
# 10    67482400                         Marine Street, Rotherhithe         2
# 11    57591213                           George Row, London, SE16         1
# 12    56498748                       Trothy Road, Bermondsey, SE1         2
# 13    70109449   More Copper House, 14-16 Magdalen Street, London         1
# 14    70107844                           Troon Close, Troon Close         3
# 15    60314193                Nemus Apartments, Surrey Quays, SE8         3
# 16    79491086            Archers Lodge , Bermondsey, London SE16         1
# 17    59610576                       Thorburn Square, London, SE1         1
# 18    79481501      Solarium Court, 105 Alscot Road, Londond, SE1         1
# 19    79480355           Landmann House, Rennie Estate , SE16 3PF         2
# 20    73920530                      Cadbury Way, Bermondsey, SE16         1
# 21    59628684                        Thorburn Square, Bermondsey         2
# 22    79466636                   St Helena Road, London, SE16 2QU         1
# 23    70043692                   Silwood Street, South Bermondsey         2
# 24    60242208                        Monnow Road, Bermondsey SE1         1
# 25    79429511                Varcoe Road,\r\nLondon,\r\nSE16 3DG         1
# 26    79429139                Varcoe Road,\r\nLondon,\r\nSE16 3DG         1
# 27    57737700                       Millender Walk, Surrey Quays         4
# 28    60231192           Kellow House, Tennis Street, London, SE1         1
# 29    60231090                                  51 Silwood Street         2
# ..         ...                                                ...       ...
# 184   69635977                      Yaldham House, Southwark, SE1         4
# 185   66835693  Tower Bridge Buildings, Mill Street, London, L...         1
# 186   66285943                       Longfield Estate, Bermondsey         3
# 187   54890475                       Oxley Close, Bermondsey, SE1         1
# 188   72279407                 The Rise, Lant Street, London, SE1         1
# 189   50439231                     Corelli Court, Lynton Road SE1         2
# 190   61813615               Yalding Road, South Bermondsey, SE16         2
# 191   64068490                          Congreve Street, Walworth         5
# 192   65155318       Freemantle Street, Elephant and Castle, SE17         2
# 193   59774920               Upnor Way, Elephant and Castle, SE17         1
# 194   68961157              Oliver House, George Row, London SE16         1
# 195   51780960                           Yalding Road, Bermondsey         2
# 196   68033482             Chaucer Drive, Bermondsey, London, SE1         1
# 197   76480409                       Rotherhithe Old Road, London         3
# 198   73657628                         Falmouth Road, London, SE1         2
# 199   72789584                        St. Saviours Estate, London         3
# 200   54199785         Tempus Wharf, Axis Court, Shad Thames SE16         1
# 201   60159856                  Borough High Street, Borough, SE1         1
# 202   56441511            Kinglake Estate, Walworth, London, SE17         3
# 203   52038975       West Grove, Orchard View, Elephant Park, SE1         1
# 204   70457744                    Tanner Street London Bridge SE1         2
# 205   52988391                                        Cadbury Way         1
# 206   43420152                                  Long Lane, London         1
# 207   71062724     Canute Gardens, Surrey Quays, London, SE16 2PN         3
# 208   63191386                   Rowcross Street, Bermondsey, SE1         2
# 209   51564261  Chancellor House, 395 Rotherhithe New Road, Lo...         1
# 210   75367874                      Henley Drive, Bermondsey, SE1         2
# 211   36996843              Newington Causeway, Elephant & Castle         2
# 212   53171204                                 Long Lane, Borough         2
# 213   58744983                     Empire Square South London SE1         1
#
#            price   property_types  \
# 0       £350,000             flat
# 1       £460,000             flat
# 2       £375,000        maisonett
# 3       £360,000             flat
# 4       £340,000             flat
# 5       £285,000             flat
# 6       £350,000           duplex
# 7       £450,000             flat
# 8       £500,000        apartment
# 9       £415,000             flat
# 10      £495,000             flat
# 11      £375,000        apartment
# 12      £500,000   terraced house
# 13      £500,000         property
# 14      £500,000             flat
# 15      £470,000        apartment
# 16      £325,000             flat
# 17      £325,000             flat
# 18      £320,000             flat
# 19      £255,000             flat
# 20      £275,000             flat
# 21      £400,000             flat
# 22      £270,000             flat
# 23      £475,000             flat
# 24      £349,000             flat
# 25   Coming Soon        apartment
# 26   Coming Soon        apartment
# 27      £400,000             flat
# 28      £375,000        apartment
# 29      £200,000             flat
# ..           ...              ...
# 184     £499,950             flat
# 185     £460,000             flat
# 186     £399,950             flat
# 187     £280,000        apartment
# 188     £500,000             flat
# 189     £440,000             flat
# 190     £400,000             flat
# 191     £474,950             flat
# 192     £400,000             flat
# 193     £279,995             flat
# 194     £397,000             flat
# 195     £400,000             flat
# 196     £325,000        maisonett
# 197     £325,000             flat
# 198     £425,000             flat
# 199     £434,999             flat
# 200     £495,000        apartment
# 201     £485,000             flat
# 202     £355,000             flat
# 203     £499,000             flat
# 204     £485,000             flat
# 205     £255,000             flat
# 206     £339,950             flat
# 207     £460,000             flat
# 208     £395,000        maisonett
# 209     £425,000        apartment
# 210     £430,000             flat
# 211          NaN             flat
# 212          NaN             flat
# 213          NaN             flat
#
#                                          property_link reduced/added  \
# 0    https://www.rightmove.co.uk//property-for-sale...        Added
# 1    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 2    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 3    https://www.rightmove.co.uk//property-for-sale...        Added
# 4    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 5    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 6    https://www.rightmove.co.uk//property-for-sale...        Added
# 7    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 8    https://www.rightmove.co.uk//property-for-sale...      Reduced
# 9    https://www.rightmove.co.uk//property-for-sale...        Added
# 10   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 11   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 12   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 13   https://www.rightmove.co.uk//property-for-sale...        Added
# 14   https://www.rightmove.co.uk//property-for-sale...        Added
# 15   https://www.rightmove.co.uk//property-for-sale...        Added
# 16   https://www.rightmove.co.uk//property-for-sale...        Added
# 17   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 18   https://www.rightmove.co.uk//property-for-sale...        Added
# 19   https://www.rightmove.co.uk//property-for-sale...        Added
# 20   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 21   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 22   https://www.rightmove.co.uk//property-for-sale...        Added
# 23   https://www.rightmove.co.uk//property-for-sale...        Added
# 24   https://www.rightmove.co.uk//property-for-sale...        Added
# 25   https://www.rightmove.co.uk//property-for-sale...        Added
# 26   https://www.rightmove.co.uk//property-for-sale...        Added
# 27   https://www.rightmove.co.uk//property-for-sale...      Reduced
# 28   https://www.rightmove.co.uk//property-for-sale...        Added
# 29   https://www.rightmove.co.uk//property-for-sale...        Added
# ..                                                 ...           ...
# 184  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 185  https://www.rightmove.co.uk//property-for-sale...        Added
# 186  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 187  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 188  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 189  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 190  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 191  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 192  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 193  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 194  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 195  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 196  https://www.rightmove.co.uk//property-for-sale...        Added
# 197  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 198  https://www.rightmove.co.uk//property-for-sale...        Added
# 199  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 200  https://www.rightmove.co.uk//property-for-sale...        Added
# 201  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 202  https://www.rightmove.co.uk//property-for-sale...        Added
# 203  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 204  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 205  https://www.rightmove.co.uk//property-for-sale...        Added
# 206  https://www.rightmove.co.uk//property-for-sale...        Added
# 207  https://www.rightmove.co.uk//property-for-sale...        Added
# 208  https://www.rightmove.co.uk//property-for-sale...        Added
# 209  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 210  https://www.rightmove.co.uk//property-for-sale...        Added
# 211  https://www.rightmove.co.uk//property-for-sale...        Added
# 212  https://www.rightmove.co.uk//property-for-sale...      Reduced
# 213  https://www.rightmove.co.uk//property-for-sale...      Reduced
#
#       date_reduced/added  no_pictures   latitude  longitude  \
# 0    2019-02-21 00:00:00            5  51.488241  -0.059255
# 1    2019-02-21 00:00:00           13  51.501119  -0.098831
# 2    2019-02-21 00:00:00            7  51.488626  -0.072841
# 3    2019-02-21 00:00:00            8  51.490291  -0.046939
# 4    2019-02-20 00:00:00            9  51.493896  -0.073088
# 5    2019-02-20 00:00:00           13  51.487690  -0.060750
# 6    2019-02-20 00:00:00            2  51.487969  -0.073389
# 7    2019-02-20 00:00:00            6  51.491540  -0.081470
# 8    2019-02-19 00:00:00            9  51.501333  -0.098619
# 9    2019-02-19 00:00:00           10  51.497324  -0.073175
# 10   2019-02-18 00:00:00            7  51.497108  -0.069675
# 11   2019-02-18 00:00:00           12  51.500777  -0.068530
# 12   2019-02-18 00:00:00           14  51.491714  -0.066445
# 13   2019-02-18 00:00:00            9  51.503708  -0.082487
# 14   2019-02-18 00:00:00            8  51.487271  -0.059612
# 15   2019-02-16 00:00:00           14  51.490800  -0.044725
# 16   2019-02-16 00:00:00            5  51.485610  -0.065010
# 17   2019-02-15 00:00:00           14  51.491250  -0.069489
# 18   2019-02-15 00:00:00            9  51.493660  -0.074599
# 19   2019-02-15 00:00:00            6  51.490440  -0.058180
# 20   2019-02-15 00:00:00            9  51.494160  -0.071280
# 21   2019-02-14 00:00:00           15  51.491170  -0.069670
# 22   2019-02-14 00:00:00            6  51.490530  -0.047370
# 23   2019-02-14 00:00:00           13  51.489720  -0.052880
# 24   2019-02-13 00:00:00           15  51.490242  -0.067970
# 25   2019-02-13 00:00:00            9  51.485120  -0.057110
# 26   2019-02-13 00:00:00            9  51.485120  -0.057110
# 27   2019-02-13 00:00:00           16  51.489880  -0.051720
# 28   2019-02-13 00:00:00            5  51.501911  -0.091268
# 29   2019-02-13 00:00:00            7  51.487571  -0.048546
# ..                   ...          ...        ...        ...
# 184  2018-08-13 00:00:00           10  51.491142  -0.082523
# 185  2018-07-08 00:00:00            5  51.500404  -0.072324
# 186  2018-02-08 00:00:00            7  51.491510  -0.073840
# 187  2018-07-23 00:00:00            8  51.488996  -0.072767
# 188  2018-07-23 00:00:00            8  51.501054  -0.095623
# 189  2018-07-23 00:00:00           10  51.489600  -0.062087
# 190  2018-07-16 00:00:00           11  51.493225  -0.070279
# 191  2018-07-16 00:00:00            1  51.490690  -0.084218
# 192  2018-11-07 00:00:00            6  51.489531  -0.082461
# 193  2018-06-07 00:00:00            6  51.487668  -0.079573
# 194  2018-06-07 00:00:00            9  51.499780  -0.068300
# 195  2018-06-29 00:00:00           14  51.493430  -0.070150
# 196  2018-06-20 00:00:00            6  51.490248  -0.074214
# 197  2018-08-06 00:00:00           15  51.492622  -0.048280
# 198  2018-06-06 00:00:00            8  51.495800  -0.094110
# 199  2018-10-05 00:00:00            7  51.498333  -0.078609
# 200  2018-03-05 00:00:00            8  51.500930  -0.067390
# 201  2018-04-25 00:00:00            9  51.500830  -0.094392
# 202  2018-04-16 00:00:00            9  51.488682  -0.079100
# 203  2018-06-04 00:00:00           10  51.495700  -0.099300
# 204  2018-03-26 00:00:00            6  51.500420  -0.079950
# 205  2018-02-16 00:00:00            7  51.494160  -0.071280
# 206  2016-02-08 00:00:00            9  51.499832  -0.087563
# 207  2018-01-19 00:00:00            8  51.492540  -0.049450
# 208  2017-12-15 00:00:00            7  51.488303  -0.073900
# 209  2017-12-13 00:00:00            8  51.484934  -0.066267
# 210  2017-03-10 00:00:00            8  51.493695  -0.073161
# 211  2015-10-15 00:00:00            0  51.495970  -0.099290
# 212  2015-08-14 00:00:00            0  51.501120  -0.089860
# 213           2019-11-02            8  51.500140  -0.090040
#
#                                             agent_name   agent_number  \
# 0                               Foxtons, London Bridge  020 8012 6757
# 1                               Foxtons, London Bridge  020 8012 6757
# 2    Alex Neil Estate Agents, South East London - S...  020 8012 0319
# 3                                      Kallars, London  020 8012 6994
# 4                      Stirling Ackroyd, London Bridge  020 8012 2405
# 5     Kinleigh Folkard & Hayward - Sales, Canada Water  020 8012 2766
# 6    Alex Neil Estate Agents, South East London - S...  020 8012 0319
# 7    Kinleigh Folkard & Hayward - Sales, London Bridge  020 8012 2031
# 8                        Purplebricks, covering London  0121 396 0233
# 9                        Purplebricks, covering London  0121 396 0233
# 10                              Dexters, London Bridge  020 7650 5100
# 11                       Purplebricks, covering London  0121 396 0233
# 12                       Purplebricks, covering London  0121 396 0233
# 13            Chestertons Estate Agents , Tower Bridge  020 8012 3880
# 14                              Dexters, London Bridge  020 7650 5100
# 15                     Metro Village Ltd, Canada Water  020 8012 4828
# 16                    My Online Estate Agent, National   03332 402712
# 17                       Purplebricks, covering London  0121 396 0233
# 18                              Williams Lynch, London  020 8012 2590
# 19                               Hunters, Surrey Quays  020 8012 4439
# 20           Beresford Residential, Camberwell - Sales  020 8012 5978
# 21   Kinleigh Folkard & Hayward - Sales, London Bridge  020 8012 2031
# 22                               Hunters, Surrey Quays  020 8012 4439
# 23    Kinleigh Folkard & Hayward - Sales, Canada Water  020 8012 2766
# 24                             Urban Patchwork, London  020 8012 0562
# 25                                       Pocket Living  020 8012 4882
# 26                                       Pocket Living  020 8012 4882
# 27    Kinleigh Folkard & Hayward - Sales, Canada Water  020 8012 2766
# 28                   Kalmars Residential , Shad Thames  020 8012 7289
# 29                         L&Q, L&Q Re Sale Membership  020 8012 0559
# ..                                                 ...            ...
# 184                             Foxtons, London Bridge  020 8012 6757
# 185                            House Network, National   01245 930165
# 186  Kinleigh Folkard & Hayward - Sales, London Bridge  020 8012 2031
# 187                      Purplebricks, covering London  0121 396 0233
# 188                    Stirling Ackroyd, London Bridge  020 8012 2405
# 189                              Leonard Leese, London  020 8012 3009
# 190                             Foxtons, London Bridge  020 8012 6757
# 191                          Davis & Gibbs Ltd, London  020 8012 1115
# 192                             Foxtons, London Bridge  020 8012 6757
# 193                             Foxtons, London Bridge  020 8012 6757
# 194                       ludlowthompson, Canada Water  020 8012 6536
# 195   Kinleigh Folkard & Hayward - Sales, Canada Water  020 8012 2766
# 196                             Williams Lynch, London  020 8012 2590
# 197                             Property Eagle, Surrey   01903 443270
# 198                                EXLA London, London  020 3858 2720
# 199                          Doorsteps.co.uk, National   01298 445019
# 200                   Chase Evans, Elephant and Castle  020 3858 2444
# 201                             Foxtons, London Bridge  020 8012 6757
# 202                    YOUR MOVE - Pereira, Camberwell  020 8012 3817
# 203                                Moving City, London  020 8012 4623
# 204                               Acorn, London Bridge  020 8012 2625
# 205      Martin & Co, London Bridge - Lettings & Sales  020 8012 6166
# 206                         McMahon & Partners, London  020 3858 2774
# 207                              Hunters, Surrey Quays  020 8012 4439
# 208                             Foxtons, London Bridge  020 8012 6757
# 209              Hastings International, London Bridge  020 8012 3343
# 210                             Williams Lynch, London  020 8012 2590
# 211  Kinleigh Folkard & Hayward - Sales, London Bridge  020 8012 2031
# 212  Kinleigh Folkard & Hayward - Sales, London Bridge  020 8012 2031
# 213                               Acorn, London Bridge  020 8012 2625
#
#     most_recent_scrape_date initial_scrape_date
# 0                22/02/2019          22-02-2019
# 1                22/02/2019          21/02/2019
# 2                22/02/2019          21/02/2019
# 3                22/02/2019          21-02-2019
# 4                22/02/2019          21/02/2019
# 5                22/02/2019          21/02/2019
# 6                22/02/2019          21/02/2019
# 7                22/02/2019          21/02/2019
# 8                22/02/2019          21/02/2019
# 9                22/02/2019          21/02/2019
# 10               22/02/2019          21/02/2019
# 11               22/02/2019          21/02/2019
# 12               22/02/2019          21/02/2019
# 13               22/02/2019          21/02/2019
# 14               22/02/2019          21/02/2019
# 15               22/02/2019          21/02/2019
# 16               22/02/2019          21/02/2019
# 17               22/02/2019          21/02/2019
# 18               22/02/2019          21/02/2019
# 19               22/02/2019          21/02/2019
# 20               22/02/2019          21/02/2019
# 21               22/02/2019          21/02/2019
# 22               22/02/2019          21/02/2019
# 23               22/02/2019          21/02/2019
# 24               22/02/2019          21/02/2019
# 25               22/02/2019          21/02/2019
# 26               22/02/2019          21/02/2019
# 27               22/02/2019          21/02/2019
# 28               22/02/2019          21/02/2019
# 29               22/02/2019          21/02/2019
# ..                      ...                 ...
# 184              22/02/2019          21/02/2019
# 185              22/02/2019          21/02/2019
# 186              22/02/2019          21/02/2019
# 187              22/02/2019          21/02/2019
# 188              22/02/2019          21/02/2019
# 189              22/02/2019          21/02/2019
# 190              22/02/2019          21/02/2019
# 191              22/02/2019          21/02/2019
# 192              22/02/2019          21/02/2019
# 193              22/02/2019          21/02/2019
# 194              22/02/2019          21/02/2019
# 195              22/02/2019          21/02/2019
# 196              22/02/2019          21/02/2019
# 197              22/02/2019          21/02/2019
# 198              22/02/2019          21/02/2019
# 199              22/02/2019          21/02/2019
# 200              22/02/2019          21/02/2019
# 201              22/02/2019          21/02/2019
# 202              22/02/2019          21/02/2019
# 203              22/02/2019          21/02/2019
# 204              22/02/2019          21/02/2019
# 205              22/02/2019          21/02/2019
# 206              22/02/2019          21/02/2019
# 207              22/02/2019          21/02/2019
# 208              22/02/2019          21/02/2019
# 209              22/02/2019          21/02/2019
# 210              22/02/2019          21/02/2019
# 211              21/02/2019          21/02/2019
# 212              21/02/2019          21/02/2019
# 213              21/02/2019          21/02/2019
#
# [214 rows x 15 columns]
