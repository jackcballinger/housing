# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import time
from datetime import datetime
import glob
import os
# import create_schroders_cert

def timer(wait_time):
    print("waiting for timer: " + str(wait_time) + "s")
    time.sleep(wait_time)

def import_previous_file():
    list_of_files = glob.glob('C:/Users/ballinj/housing/data/zoopla/*.csv')
    latest_file = max(list_of_files, key=os.path.getctime)
    combined_df_old = pd.read_csv(latest_file, index_col=0)
    return combined_df_old 
    
def get_soup(url, payload):
    cert = "C:/Users/ballinj/housing/ca-certificates.crt"
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1667.0 Safari/537.36'}
    r = requests.get(url, verify=cert, headers=headers, params=payload)
    c = r.content    
    soup = BeautifulSoup(c, 'html.parser')
    return(soup)

def get_no_pages(soup):
    try:
        page_box = soup.find('div', attrs={'class':'paginate bg-muted'})
        no_pages = page_box.findAll('a')
        no_pages = int([page.text.strip() for page in no_pages][:-1][-1])
    except AttributeError:
        no_pages = 1
    return no_pages

def get_no_results(soup):
    no_results = int(soup.find('span', attrs={'class':'listing-results-utils-count'}).text.strip().split(' ')[-1])
    return no_results

def get_listing_df(no_pages):
    index_array = np.arange(1,no_pages+1).tolist()
    listing_ids, links, property_types, addresses, prices_per_month, prices_per_week, featured_properties = [],[],[],[],[],[],[]
    nearest_station_array, nearest_station_dict = [],[]
    for index in index_array:
        url = 'https://www.zoopla.co.uk/to-rent/property/bermondsey/?'
        payload = {'beds_min':'1',
                   'include_shared_accommodation':'false',
                   'price_frequency':'per_month',
                   'price_max':'1750',
                   'q':'Bermondsey, London',
                   'results_sort':'newest_listings',
                   'search_source':'home',
                   'page_size':'100',
                   'pn': index}
        soup = get_soup(url, payload)
        search_results = soup.find('ul', attrs={'class':'listing-results clearfix js-gtm-list'})
        property_boxes = search_results.findAll('div', attrs={'class':'listing-results-wrapper'})
        for property_box in property_boxes:
            listing_ids.append(property_box.parent['data-listing-id'].strip())
            links.append('https://www.zoopla.co.uk' + str(property_box.find('a')['href']))
            addresses.append(property_box.find('a', attrs={'class':'listing-results-address'}).text)
            property_types.append(property_box.find('h2',attrs={'class':'listing-results-attr'}).find('a').text.strip())
            prices = property_box.find('a', attrs={'class':'listing-results-price text-price'}).text.strip()
            prices_per_month.append(prices.split('(')[0].strip())
            prices_per_week.append(prices.split('(')[1].replace(')',"").strip())
            if property_box.parent['class'][2] != "":
                featured_properties.append(property_box.parent['class'][2].strip())
            else:
                featured_properties.append("")
            station_box = property_box.find('div', attrs={'class':'nearby_stations_schools clearfix'})
            stations = station_box.findAll('li')
            property_station_array = []
            for station in stations:
                single_station_array = []
                single_station_array.append(station.find('span', attrs={'class':'nearby_stations_schools_name'})['title'])
                single_station_array.append(station.text.strip().split('   ')[-1])
                property_station_array.append(single_station_array)
            nearest_station_array.append(property_station_array)

            station_dict = {item[0]: item[1] for item in property_station_array}
            nearest_station_dict.append(station_dict)
        
    listing_df = pd.DataFrame(listing_ids, columns=['listing_id'])
    listing_df['address'] = addresses
    listing_df['property_type'] = property_types
    listing_df['property_link'] = links
    listing_df['price_per_month'] = prices_per_month
    listing_df['featured_property'] = featured_properties
    listing_df = listing_df.reset_index(drop=True)
    return listing_df, nearest_station_array, nearest_station_dict

def get_details_df(listing_df):
    dates_available, furnishings, descriptions, initial_scraped_dates, most_recent_scraped_dates, longitudes, latitudes = [],[],[],[],[],[],[]
    for index, row in listing_df.iterrows():
        url = row['property_link']
        print(url)
        print(str(index + 1) + ' out of ' + str(len(listing_df)))
        timer(2)
        soup = get_soup(url,payload="")
        page_info = soup.find('div', attrs={'class':'dp-tabs'})
        property_details_tab = page_info.find('section', attrs={'id':'property-details-tab'})
        features = property_details_tab.find('ul', attrs={'class':'dp-features-list ui-list-icons'})
        script = str(soup.findAll('script', attrs={'type':'application/ld+json'})[-1].text)

        try:
            furnishings.append(features.find('svg', attrs={'class':'ui-icon icon-chair'}).parent.find('span').text.strip())
        except AttributeError:
            furnishings.append(None)

        try:
            dates_available.append(features.find('svg', attrs={'class':'ui-icon icon-calendar'}).parent.find('span').text.split('from')[1].strip())
        except AttributeError:
            dates_available.append(None)

        try:
            descriptions.append(property_details_tab.find('div', attrs={'class':'dp-description__text'}).text.strip())
        except AttributeError:
            descriptions.append(None)

        try:
            latitudes.append(script[script.find('latitude')+12:script[script.find('latitude')+12:].find(",")+script.find('latitude')+11])
        except AttributeError:
            latitudes.append(None)

        try:
            longitudes.append(script[script.find('longitude')+13:script[script.find('longitude')+14:].find('"')+script.find('longitude')+14])
        except AttributeError:
            longitudes.append(None)
        
        most_recent_scraped_dates = today
        if int(row['listing_id']) not in combined_df_old['listing_id'].tolist():
            initial_scraped_dates.append(today)
        else:
            initial_scraped_dates.append(combined_df_old[combined_df_old['listing_id']==int(row['listing_id'])]['initial_scrape_date'].tolist()[0])
        
    details_df = pd.DataFrame(dates_available, columns=['dates_available'])
    details_df['furnishing'] = furnishings
    details_df['description'] = descriptions
    details_df['longitude'] = longitudes
    details_df['latitude'] = latitudes
    details_df['initial_scrape_date'] = initial_scraped_dates
    details_df['most_recent_scrape_date'] = most_recent_scraped_dates
    return details_df

def get_updated_stations(no_pages):
    index_array = np.arange(1,no_pages+1).tolist()
    total_stations = []
    for index in index_array:
        url = 'https://www.zoopla.co.uk/to-rent/property/bermondsey/?'
        payload = {'beds_min':'1',
                   'include_shared_accommodation':'false',
                   'price_frequency':'per_month',
                   'price_max':'1750',
                   'q':'Bermondsey, London',
                   'results_sort':'newest_listings',
                   'search_source':'home',
                   'page_size':'100',
                   'pn': index}
        soup = get_soup(url, payload)
        search_results = soup.find('ul', attrs={'class':'listing-results clearfix js-gtm-list'})
        property_boxes = search_results.findAll('div', attrs={'class':'listing-results-wrapper'})
        for property_box in property_boxes:
            station_box = property_box.find('div', attrs={'class':'nearby_stations_schools clearfix'})
            stations = station_box.findAll('li')
            for station in stations:
                total_stations.append(station.find('span')['title'])
    total_stations = pd.Series(total_stations)
    total_stations = pd.Series(total_stations.unique()).sort_values()
    return total_stations

def get_station_df(nearest_stations_array, nearest_stations_dict, stations_array):
    station_array = []
    for property in nearest_stations_array:
        station_array_temp_mid = []
        for row in property:
            station_array_temp_small = []
            for station in stations_array:
                try:
                    if row[0] == station:
                        station_array_temp_small.append(row[0])
                    else:
                        station_array_temp_small.append(None)
                except:
                    continue
            station_array_temp_mid.append(station_array_temp_small)
        station_array.append(station_array_temp_mid)

    station_array

    stations_sparse_array = []
    for location in station_array:
        combined_station_array = []
        for a,b in zip(location[0],location[1]):
            if a != None:
                combined_station_array.append(a)
            elif b != None:
                combined_station_array.append(b)
            else:
                combined_station_array.append(None)
        stations_sparse_array.append(combined_station_array)

    distances_sparse_array = []
    dict_counter = 0
    for location in stations_sparse_array:
        distances = []
        for datapoint in location:
            if datapoint in nearest_stations_dict[dict_counter].keys():
                distances.append(nearest_stations_dict[dict_counter][datapoint].replace('(',"").replace(')',""))
            else:
                distances.append(None)
        distances_sparse_array.append(distances)
        dict_counter = dict_counter + 1
    stations_df = pd.DataFrame(distances_sparse_array, columns=stations_array)
    return stations_df

today = datetime.today().strftime("%d-%m-%Y")

url = 'https://www.zoopla.co.uk/to-rent/property/bermondsey/?beds_min=1&include_shared_accommodation=false&price_frequency=per_month&price_max=1750&q=Bermondsey%2C%20London&results_sort=newest_listings&search_source=home&page_size=100'
soup = get_soup(url, payload="")
combined_df_old = import_previous_file()
no_pages = get_no_pages(soup)
listing_df, nearest_stations_array, nearest_stations_dict = get_listing_df(no_pages)
stations_array = get_updated_stations(no_pages)
station_df = get_station_df(nearest_stations_array, nearest_stations_dict, stations_array)
details_df = get_details_df(listing_df)
combined_df = pd.concat([listing_df, details_df, station_df], axis=1)
for index, row in combined_df_old.iterrows():
    if int(row['listing_id']) not in [int(id) for id in combined_df['listing_id'].tolist()]:
        combined_df = combined_df.append(row)
combined_df = combined_df.reset_index(drop=True)
combined_df.to_csv('C:/Users/ballinj/housing/data/zoopla/housing_data_{}.csv'.format(today))
# Out:
# https://www.zoopla.co.uk/to-rent/details/50471046?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 1 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50470962?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 2 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50469200?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 3 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50463331?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 4 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50460854?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 5 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50459559?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 6 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50429654?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 7 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50459073?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 8 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50458903?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 9 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50458470?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 10 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50448337?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 11 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50448338?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 12 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50444064?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 13 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45915233?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 14 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47108722?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 15 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50437625?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 16 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50432157?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 17 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50431378?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 18 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50429517?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 19 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50428548?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 20 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50421452?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 21 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50421144?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 22 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50419845?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 23 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/46853753?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 24 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50415226?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 25 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50407688?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 26 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50394994?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 27 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50386391?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 28 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/46483533?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 29 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50374191?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 30 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50369884?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 31 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50361910?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 32 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50362462?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 33 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50358242?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 34 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50358112?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 35 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50353574?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 36 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50344084?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 37 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/46382733?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 38 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50339963?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 39 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50339966?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 40 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48526106?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 41 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/40993088?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 42 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50328677?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 43 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50328540?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 44 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50320740?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 45 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/33800254?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 46 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50310576?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 47 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50308760?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 48 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50303956?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 49 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50300008?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 50 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50285156?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 51 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50284000?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 52 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44285227?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 53 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50280914?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 54 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50271734?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 55 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45577147?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 56 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50259486?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 57 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50243140?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 58 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50237610?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 59 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50223743?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 60 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50207663?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 61 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50195869?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 62 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50189813?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 63 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50188469?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 64 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/43992941?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 65 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50186936?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 66 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50365633?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 67 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44206542?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 68 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50182681?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 69 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50176579?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 70 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/46341107?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 71 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50158750?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 72 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45023552?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 73 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383536?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 74 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/46839510?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 75 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50134072?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 76 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383534?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 77 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383533?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 78 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47776687?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 79 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50115056?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 80 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50114304?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 81 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48640089?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 82 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47811312?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 83 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44756730?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 84 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44706252?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 85 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44882208?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 86 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/40280816?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 87 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50113780?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 88 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383530?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 89 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50096763?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 90 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50086165?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 91 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50071947?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 92 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/41737668?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 93 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/16685237?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 94 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383520?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 95 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48530036?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 96 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49968801?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 97 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49968502?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 98 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45630949?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 99 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49930659?search_identifier=06b0d38bbf12e02e8249d145307ae214
# 100 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49923482?search_identifier=79762792e21a1c2d930554e051666d2f
# 101 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49915123?search_identifier=79762792e21a1c2d930554e051666d2f
# 102 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49897938?search_identifier=79762792e21a1c2d930554e051666d2f
# 103 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49887931?search_identifier=79762792e21a1c2d930554e051666d2f
# 104 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49887850?search_identifier=79762792e21a1c2d930554e051666d2f
# 105 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49855631?search_identifier=79762792e21a1c2d930554e051666d2f
# 106 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49851681?search_identifier=79762792e21a1c2d930554e051666d2f
# 107 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383347?search_identifier=79762792e21a1c2d930554e051666d2f
# 108 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49830995?search_identifier=79762792e21a1c2d930554e051666d2f
# 109 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49827059?search_identifier=79762792e21a1c2d930554e051666d2f
# 110 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45272911?search_identifier=79762792e21a1c2d930554e051666d2f
# 111 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49743691?search_identifier=79762792e21a1c2d930554e051666d2f
# 112 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383321?search_identifier=79762792e21a1c2d930554e051666d2f
# 113 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49689760?search_identifier=79762792e21a1c2d930554e051666d2f
# 114 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/43759054?search_identifier=79762792e21a1c2d930554e051666d2f
# 115 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49623938?search_identifier=79762792e21a1c2d930554e051666d2f
# 116 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49609160?search_identifier=79762792e21a1c2d930554e051666d2f
# 117 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49580421?search_identifier=79762792e21a1c2d930554e051666d2f
# 118 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49565271?search_identifier=79762792e21a1c2d930554e051666d2f
# 119 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383135?search_identifier=79762792e21a1c2d930554e051666d2f
# 120 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383325?search_identifier=79762792e21a1c2d930554e051666d2f
# 121 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383521?search_identifier=79762792e21a1c2d930554e051666d2f
# 122 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49311949?search_identifier=79762792e21a1c2d930554e051666d2f
# 123 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/49302516?search_identifier=79762792e21a1c2d930554e051666d2f
# 124 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/50383527?search_identifier=79762792e21a1c2d930554e051666d2f
# 125 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48951362?search_identifier=79762792e21a1c2d930554e051666d2f
# 126 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/3503492?search_identifier=79762792e21a1c2d930554e051666d2f
# 127 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48853758?search_identifier=79762792e21a1c2d930554e051666d2f
# 128 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44987306?search_identifier=79762792e21a1c2d930554e051666d2f
# 129 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44355216?search_identifier=79762792e21a1c2d930554e051666d2f
# 130 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/48311843?search_identifier=79762792e21a1c2d930554e051666d2f
# 131 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47853437?search_identifier=79762792e21a1c2d930554e051666d2f
# 132 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44029083?search_identifier=79762792e21a1c2d930554e051666d2f
# 133 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47510568?search_identifier=79762792e21a1c2d930554e051666d2f
# 134 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/47130451?search_identifier=79762792e21a1c2d930554e051666d2f
# 135 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45258556?search_identifier=79762792e21a1c2d930554e051666d2f
# 136 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/45005429?search_identifier=79762792e21a1c2d930554e051666d2f
# 137 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/41085886?search_identifier=79762792e21a1c2d930554e051666d2f
# 138 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/30476267?search_identifier=79762792e21a1c2d930554e051666d2f
# 139 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/36139849?search_identifier=79762792e21a1c2d930554e051666d2f
# 140 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/39237336?search_identifier=79762792e21a1c2d930554e051666d2f
# 141 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/39426001?search_identifier=79762792e21a1c2d930554e051666d2f
# 142 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44335614?search_identifier=79762792e21a1c2d930554e051666d2f
# 143 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/44164823?search_identifier=79762792e21a1c2d930554e051666d2f
# 144 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/43289958?search_identifier=79762792e21a1c2d930554e051666d2f
# 145 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/43189679?search_identifier=79762792e21a1c2d930554e051666d2f
# 146 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/42804726?search_identifier=79762792e21a1c2d930554e051666d2f
# 147 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/41577793?search_identifier=79762792e21a1c2d930554e051666d2f
# 148 out of 149
# waiting for timer: 2s
# https://www.zoopla.co.uk/to-rent/details/36170096?search_identifier=79762792e21a1c2d930554e051666d2f
# 149 out of 149
# waiting for timer: 2s

# %%
url = 'https://www.zoopla.co.uk/to-rent/details/50471046?search_identifier=d4d865b7d6adeffd5ba21fccceee0084'
soup = get_soup(url,payload="")

agent_name, agent_address = [],[]
secondary_details = soup.find('div', attrs={'class':'dp-sidebar-wrapper'}).find('div', attrs={'class':'dp-sidebar-wrapper__contact'})
agent_details = secondary_details.find('div', attrs={'class':'ui-agent__text'})
agent_name.append(agent_details.find('h4', attrs={'class':'ui-agent__name'}).text.strip())
agent_address.append(agent_details.find('address',attrs={'class':'ui-agent__address'}).text.strip())
# Out:
# '329-339 Putney Bridge Road, Putney, SW15 2PG'

# %%
tel_field = secondary_details.find('p', attrs={'class':'ui-agent__tel ui-agent__text'}).find('a')['href']
tel_number = tel_field[tel_field.find(':')+1:].strip()
tel_number
# Out:
# '02080220046'
